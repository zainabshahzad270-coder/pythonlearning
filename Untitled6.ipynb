# %% [markdown]
# <a href="https://colab.research.google.com/github/zainabshahzad270-coder/pythonlearning/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
print("Welcome to Google Colab")

# Simple math
a = 10
b = 5

sum = a + b
print("Sum of a and b is:", sum)
# Out:
# Hello, World!
# Welcome to Google Colab
# Sum of a and b is: 15
